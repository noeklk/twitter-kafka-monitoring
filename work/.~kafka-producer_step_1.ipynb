# %% [markdown]
# # KAFKA PRODUCER

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
import tweepy
import os
import json
from kafka import KafkaProducer

ACCESS_TOKEN="1052919765126316033-eATAf2skyDxIomK4GxYaZ7zj5Th6BX"
ACCESS_TOKEN_SECRET="fMFNeiSTpMu4kJuZx0vXYgKeizRGv8CZZQaZ2LbY576lH"
CONSUMER_KEY="0wjVKNcrlxQIlf0UKVNwpwShq"
CONSUMER_SECRET="mUoz9LP810L2bkJzfpM1e8TgK2wLmip3kc7nORjvAbwwmtKxid"

SEARCH_KEYWORD = str(input("Please enter a keyword to filter\n"))

producer = KafkaProducer(bootstrap_servers=['kafka:9092'])

def filter_tweet(tweet):
    data = json.loads(tweet)
    
    if 'delete' in data:
        return False
    if 'timestamp_ms' not in data or 'entities' not in data:
        return False      
    if len(data['entities']['hashtags']) <= 0:
        return False
        
    data = {"timestamp": data['timestamp_ms'], "hashtags": [i["text"] for i in data['entities']['hashtags']]}
    print(data)
    data = json.dumps(data)
    
    return data


class StdOutListener(StreamListener):
    def __init__(self):
        self.count=0

    def on_data(self, data):
        data = filter_tweet(data)
        if data != False:
            producer.send("tweets", data.encode('utf-8'))  
         
        self.count+=1 
        print(self.count)
        return True
    def on_error(self, status):
        print(status)
        
    def on_exception(self, exception):
        print(exception)
        return

myStreamListener = StdOutListener()
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
myStream = tweepy.Stream(auth = auth, listener=myStreamListener)
myStream.filter(track=[SEARCH_KEYWORD])

print(f"Starting tweet streams")
# Out:
# Please enter a keyword to filter
# EURO2020
# 1
# 2
# 3
# {'timestamp': '1624613012154', 'hashtags': ['EURO2020', 'MCFC']}
# 4
# 5
# {'timestamp': '1624613013382', 'hashtags': ['EURO2020']}
# 6
# 7
# {'timestamp': '1624613014569', 'hashtags': ['EURO2020']}
# 8
# 9
# 10
# {'timestamp': '1624613018012', 'hashtags': ['ESP', 'DEN', 'ITA', 'GER', 'FRA', 'NED']}
# 11
# {'timestamp': '1624613018976', 'hashtags': ['ENGGER', 'MiaSanMia', 'EURO2020']}
# 12
# 13
# {'timestamp': '1624613019878', 'hashtags': ['EURO2020']}
# 14
# {'timestamp': '1624613020086', 'hashtags': ['EURO2020']}
# 15
# {'timestamp': '1624613020374', 'hashtags': ['EURO2020']}
# 16
# {'timestamp': '1624613020537', 'hashtags': ['NazisrausausdenStadien', 'HUNGER', 'Goretzka', 'EURO2020', 'Euro2021']}
# 17
# {'timestamp': '1624613020595', 'hashtags': ['Euro2020']}
# 18
# 19
# 20
# {'timestamp': '1624613021442', 'hashtags': ['Euro2020']}
# 21
# {'timestamp': '1624613021625', 'hashtags': ['tourdefrance', 'porteclef', 'pendentif', 'nibali', 'cycling', 'ciclismo', 'bike', 'paris', 'bijoux', 'handmadejewelry']}
# 22
# 23
# {'timestamp': '1624613022373', 'hashtags': ['EURO2020']}
# 24
# {'timestamp': '1624613022382', 'hashtags': ['EURO2020']}
# 25
# 26
# {'timestamp': '1624613022520', 'hashtags': ['ManCity', 'EURO2020']}
# 27
# {'timestamp': '1624613024123', 'hashtags': ['Coronavirus', 'Euro2020']}
# 28
# 29
# 30
# 31
# 32
# {'timestamp': '1624613025798', 'hashtags': ['EURO2020']}
# 33
# {'timestamp': '1624613026159', 'hashtags': ['EURO2020']}
# 34
# 35
# {'timestamp': '1624613026213', 'hashtags': ['ITA']}
# 36
# 37
# {'timestamp': '1624613027185', 'hashtags': ['himno', 'EURO2020']}
# 38
# 39
# {'timestamp': '1624613027545', 'hashtags': ['Euro2020']}
# 40
# {'timestamp': '1624613028131', 'hashtags': ['EURO2020']}
# 41
# {'timestamp': '1624613030158', 'hashtags': ['EURO2020', 'Eurotubers']}
# 42
# 43
# 44
# {'timestamp': '1624613030580', 'hashtags': ['EURO2020', 'POR']}
# 45
# {'timestamp': '1624613030573', 'hashtags': ['EURO2020']}
# 46
# {'timestamp': '1624613030880', 'hashtags': ['EURO2020', 'CROSCO']}
# 47
# 48
# {'timestamp': '1624613032156', 'hashtags': ['Coronavirus', 'Euro2020']}
# 49
# {'timestamp': '1624613033032', 'hashtags': ['EURO2020', 'VIVOY72']}
# 50
# {'timestamp': '1624613033273', 'hashtags': ['ManCity']}
# 51
# 52
# 53
# 54
# 55
# 56
# 57
# {'timestamp': '1624613034990', 'hashtags': ['NED', 'CZE', 'BEL', 'POR', 'CRO', 'ESP']}
# 58
# {'timestamp': '1624613035166', 'hashtags': ['EURO2020']}
# 59
# {'timestamp': '1624613036248', 'hashtags': ['EURO2020']}
# 60
# {'timestamp': '1624613036399', 'hashtags': ['EUROSkills']}
# 61
# 62
# 63
# {'timestamp': '1624613039887', 'hashtags': ['EURO2020']}
# 64
# {'timestamp': '1624613040218', 'hashtags': ['ADiario', 'Euro2020']}
# 65
# {'timestamp': '1624613040237', 'hashtags': ['EURO2020']}
# 66
# {'timestamp': '1624613040328', 'hashtags': ['EURO2020']}
# 67
# 68
# {'timestamp': '1624613042745', 'hashtags': ['giveaway', 'EURO2020']}
# 69
# 70
# 71
# {'timestamp': '1624613044943', 'hashtags': ['EURO2020', 'WAL', 'DEN']}
# 72
# {'timestamp': '1624613045019', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 73
# 74
# 75
# {'timestamp': '1624613046279', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 76
# 77
# {'timestamp': '1624613047433', 'hashtags': ['EURO2020', 'POR', 'FRA']}
# 78
# {'timestamp': '1624613047502', 'hashtags': ['EURO2020']}
# 79
# 80
# 81
# 82
# {'timestamp': '1624613049627', 'hashtags': ['EURO2020', 'Heineken']}
# 83
# 84
# 85
# 86
# {'timestamp': '1624613050371', 'hashtags': ['EURO2020', 'Euros2021']}
# 87
# {'timestamp': '1624613050606', 'hashtags': ['Denmark']}
# 88
# 89
# {'timestamp': '1624613051835', 'hashtags': ['EURO2020']}
# 90
# 91
# {'timestamp': '1624613052913', 'hashtags': ['EURO2020']}
# 92
# 93
# {'timestamp': '1624613053117', 'hashtags': ['England']}
# 94
# {'timestamp': '1624613053251', 'hashtags': ['EURO2020']}
# 95
# {'timestamp': '1624613053542', 'hashtags': ['EURO2020', 'POR']}
# 96
# 97
# 98
# 99
# 100
# 101
# {'timestamp': '1624613056734', 'hashtags': ['EURO2020', 'NED']}
# 102
# 103
# 104
# 105
# {'timestamp': '1624613058124', 'hashtags': ['EURO2020']}
# 106
# {'timestamp': '1624613058165', 'hashtags': ['ManCity', 'EURO2020']}
# 107
# 108
# {'timestamp': '1624613058473', 'hashtags': ['EURO2020']}
# 109
# 110
# {'timestamp': '1624613060130', 'hashtags': ['WAL', 'EURO2020', 'TogetherStronger']}
# 111
# 112
# {'timestamp': '1624613061174', 'hashtags': ['EURO2020', 'POR']}
# 113
# 114
# 115
# {'timestamp': '1624613061819', 'hashtags': ['ITA']}
# 116
# 117
# {'timestamp': '1624613063329', 'hashtags': ['EURO2020']}
# 118
# {'timestamp': '1624613064821', 'hashtags': ['COVID']}
# 119
# {'timestamp': '1624613065381', 'hashtags': ['ENG', 'GER']}
# 120
# {'timestamp': '1624613066317', 'hashtags': ['EURO2020']}
# 121
# {'timestamp': '1624613067385', 'hashtags': ['EURO2020']}
# 122
# {'timestamp': '1624613067538', 'hashtags': ['WAL', 'EURO2020', 'TogetherStronger']}
# 123
# {'timestamp': '1624613067649', 'hashtags': ['EURO2020']}
# 124
# 125
# 126
# {'timestamp': '1624613069337', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 127
# {'timestamp': '1624613069934', 'hashtags': ['EURO2020']}
# 128
# 129
# {'timestamp': '1624613070442', 'hashtags': ['EURO2020']}
# 130
# 131
# 132
# {'timestamp': '1624613071567', 'hashtags': ['EURO2020', 'WhistlePodu', 'Yellove', 'kadaikutty']}
# 133
# {'timestamp': '1624613071715', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 134
# {'timestamp': '1624613072276', 'hashtags': ['DDLZanLeggeControOmofobia']}
# 135
# {'timestamp': '1624613072476', 'hashtags': ['POR', 'CZE', 'SWE', 'BEL', 'NED', 'POL']}
# 136
# {'timestamp': '1624613072694', 'hashtags': ['EURO2020', 'MCFC']}
# 137
# {'timestamp': '1624613072954', 'hashtags': ['EURO2020', 'MCFC']}
# 138
# 139
# 140
# {'timestamp': '1624613073310', 'hashtags': ['FRA', 'POR', 'EURO2020']}
# 141
# 142
# {'timestamp': '1624613074209', 'hashtags': ['EURO2020']}
# 143
# 144
# 145
# {'timestamp': '1624613075157', 'hashtags': ['ITA', 'AUT', 'VivoAzzurro', 'ITAAUT', 'ITA']}
# 146
# {'timestamp': '1624613075449', 'hashtags': ['EURO2020']}
# 147
# {'timestamp': '1624613076795', 'hashtags': ['EURO2020']}
# 148
# 149
# 150
# 151
# {'timestamp': '1624613079684', 'hashtags': ['DieMannschaft', 'GER', 'EURO2020']}
# 152
# 153
# {'timestamp': '1624613080773', 'hashtags': ['ENG', 'GER']}
# 154
# 155
# 156
# 157
# 158
# 159
# {'timestamp': '1624613082793', 'hashtags': ['ManCity', 'ENG', 'EURO2020']}
# 160
# 161
# {'timestamp': '1624613083114', 'hashtags': ['EURO2020', 'Euro2021', 'NewMusic', 'Surf']}
# 162
# 163
# {'timestamp': '1624613083887', 'hashtags': ['ITAAUT']}
# 164
# 165
# {'timestamp': '1624613084506', 'hashtags': ['Coronavirus', 'Euro2020']}
# 166
# 167
# 168
# {'timestamp': '1624613086244', 'hashtags': ['WAL', 'EURO2020', 'TogetherStronger']}
# 169
# {'timestamp': '1624613086724', 'hashtags': ['ItaliaAustria', 'EURO2020']}
# 170
# {'timestamp': '1624613086833', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 171
# 172
# 173
# {'timestamp': '1624613086456', 'hashtags': ['WAL']}
# 174
# {'timestamp': '1624613087424', 'hashtags': ['EURO2020']}
# 175
# {'timestamp': '1624613088343', 'hashtags': ['OnThisDay', 'EURO', 'EURO2020']}
# 176
# 177
# 178
# {'timestamp': '1624613089660', 'hashtags': ['ENG', 'EURO2020', 'MCFC']}
# 179
# {'timestamp': '1624613090094', 'hashtags': ['EURO2020', 'MCFC']}
# 180
# {'timestamp': '1624613090689', 'hashtags': ['EURO2020']}
# 181
# {'timestamp': '1624613090752', 'hashtags': ['EURO2020']}
# 182
# 183
# {'timestamp': '1624613091849', 'hashtags': ['ITA']}
# 184
# {'timestamp': '1624613091838', 'hashtags': ['EURO2020']}
# 185
# {'timestamp': '1624613092465', 'hashtags': ['EURO2020']}
# 186
# {'timestamp': '1624613092965', 'hashtags': ['EURO2020']}
# 187
# {'timestamp': '1624613093093', 'hashtags': ['actualites', 'euro2020', 'olympiquelyonnais', 'equipedefrance', 'euro2021']}
# 188
# {'timestamp': '1624613093429', 'hashtags': ['Euro', 'Pogba', 'Cristiano', 'FRA', 'POR']}
# 189
# 190
# 191
# {'timestamp': '1624613093874', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 192
# 193
# 194
# 195
# {'timestamp': '1624613095854', 'hashtags': ['EURO2020']}
# 196
# 197
# 198
# {'timestamp': '1624613097774', 'hashtags': ['EURO2020']}
# 199
# {'timestamp': '1624613098157', 'hashtags': ['Euro2021', 'EURO2020']}
# 200
# {'timestamp': '1624613098499', 'hashtags': ['ManCity', 'EURO2020']}
# 201
# {'timestamp': '1624613098947', 'hashtags': ['EURO2020']}
# 202
# 203
# 204
# 205
# {'timestamp': '1624613100116', 'hashtags': ['EURO2020']}
# 206
# {'timestamp': '1624613100221', 'hashtags': ['EURO2020', 'Heineken']}
# 207
# 208
# {'timestamp': '1624613100655', 'hashtags': ['EURO2020', 'FRA', 'POR']}
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# {'timestamp': '1624613103262', 'hashtags': ['EURO2020']}
# 216
# 217
# {'timestamp': '1624613103387', 'hashtags': ['EURO2020']}
# 218
# 219
# {'timestamp': '1624613103580', 'hashtags': ['EUROSkills']}
# 220
# {'timestamp': '1624613103925', 'hashtags': ['EURO2020']}
# 221
# 222
# {'timestamp': '1624613103922', 'hashtags': ['EURO2020', 'Selbstbestimmungsgesetz', 'Blutspendeverbot']}
# 223
# {'timestamp': '1624613103953', 'hashtags': ['EURO2020']}
# 224
# {'timestamp': '1624613105067', 'hashtags': ['EURO2020', 'FRA', 'POR']}
# 225
# 226
# 227
# 228
# {'timestamp': '1624613106409', 'hashtags': ['GERHUN']}
# 229
# {'timestamp': '1624613106462', 'hashtags': ['EURO2020']}
# 230
# 231
# {'timestamp': '1624613107235', 'hashtags': ['EURO2020']}
# 232
# 233
# 234
# {'timestamp': '1624613108260', 'hashtags': ['ITA', 'AUT', 'VivoAzzurro', 'ITAAUT', 'ITA']}
# 235
# 236
# 237
# 238
# {'timestamp': '1624613109774', 'hashtags': ['EURO2020']}
# 239
# {'timestamp': '1624613111688', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 240
# {'timestamp': '1624613111974', 'hashtags': ['EURO2020']}
# 241
# {'timestamp': '1624613112277', 'hashtags': ['EURO2020']}
# 242
# 243
# 244
# {'timestamp': '1624613112936', 'hashtags': ['EURO2020']}
# 245
# 246
# {'timestamp': '1624613113659', 'hashtags': ['EURO2020']}
# 247
# {'timestamp': '1624613114128', 'hashtags': ['EURO2020']}
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# {'timestamp': '1624613120266', 'hashtags': ['EURO2020']}
# 255
# {'timestamp': '1624613120626', 'hashtags': ['ManCity', 'EURO2020']}
# 256
# {'timestamp': '1624613121576', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 257
# 258
# 259
# {'timestamp': '1624613122289', 'hashtags': ['POR', 'EURO2020']}
# 260
# {'timestamp': '1624613123149', 'hashtags': ['DieMannschaft', 'GER', 'EURO2020']}
# 261
# {'timestamp': '1624613123170', 'hashtags': ['Euro2020']}
# 262
# 263
# {'timestamp': '1624613124589', 'hashtags': ['Mariners', 'RemoveATK']}
# 264
# 265
# 266
# 267
# {'timestamp': '1624613126222', 'hashtags': ['EURO2020', 'POR']}
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# {'timestamp': '1624613130991', 'hashtags': ['EURO2020', 'packmas']}
# 277
# 278
# 279
# {'timestamp': '1624613132390', 'hashtags': ['EURO2020', 'VIVOY72']}
# 280
# 281
# 282
# {'timestamp': '1624613133212', 'hashtags': ['ITA']}
# 283
# {'timestamp': '1624613135043', 'hashtags': ['EURO2020']}
# 284
# 285
# 286
# 287
# 288
# 289
# {'timestamp': '1624613136414', 'hashtags': ['EURO2020']}
# 290
# 291
# 292
# {'timestamp': '1624613136899', 'hashtags': ['euro2020', 'europhoria', 'roundof16']}
# 293
# 294
# {'timestamp': '1624613138071', 'hashtags': ['EURO2020', 'WhistlePodu', 'Yellove', 'kadaikutty']}
# 295
# 296
# 297
# {'timestamp': '1624613138988', 'hashtags': ['UCL']}
# 298
# {'timestamp': '1624613139193', 'hashtags': ['EURO2020']}
# 299
# 300
# {'timestamp': '1624613141695', 'hashtags': ['SMSports', 'EURO2020']}
# 301
# {'timestamp': '1624613142838', 'hashtags': ['EURO2020']}
# 302
# 303
# 304
# 305
# 306
# {'timestamp': '1624613143720', 'hashtags': ['EUROfantasy', 'EURO2020']}
# 307
# {'timestamp': '1624613144199', 'hashtags': ['EURO2020']}
# 308
# {'timestamp': '1624613145045', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 309
# 310
# 311
# 312
# {'timestamp': '1624613145899', 'hashtags': ['EURO2020', 'WALDEN']}
# 313
# 314
# {'timestamp': '1624613146495', 'hashtags': ['ManCity']}
# 315
# {'timestamp': '1624613146597', 'hashtags': ['EURO2020', 'WhistlePodu', 'Yellove', 'kadaikutty']}
# 316
# 317
# {'timestamp': '1624613147616', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 318
# 319
# 320
# {'timestamp': '1624613149431', 'hashtags': ['EURO2020', 'MCFC']}
# 321
# 322
# 323
# {'timestamp': '1624613150098', 'hashtags': ['Wembley', 'EURO2020']}
# 324
# 325
# {'timestamp': '1624613150597', 'hashtags': ['EURO2020', 'Regenbogenfarben', 'Politik', 'Fussball']}
# 326
# 327
# {'timestamp': '1624613151088', 'hashtags': ['ハイセンス']}
# 328
# 329
# {'timestamp': '1624613151873', 'hashtags': ['EURO2020', 'BetWithZEbet']}
# 330
# 331
# 332
# {'timestamp': '1624613154404', 'hashtags': ['EURO2020', 'فردوسی\u200cپور']}
# 333
# {'timestamp': '1624613155265', 'hashtags': ['EURO2020', 'WhistlePodu', 'Yellove', 'kadaikutty']}
# 334
# {'timestamp': '1624613155464', 'hashtags': ['EURO2020']}
# 335
# {'timestamp': '1624613155605', 'hashtags': ['salamisbet', 'EURO2020']}
# 336
# 337
# {'timestamp': '1624613156163', 'hashtags': ['EURO2020', 'WhistlePodu', 'Yellove', 'kadaikutty']}
# 338
# 339
# 340
# 341
# 342
# {'timestamp': '1624613159321', 'hashtags': ['EURO2020', 'VIVOY72']}
# 343
# {'timestamp': '1624613159633', 'hashtags': ['VamosComTudo']}
# 344
# 345
# 346
# 347
# {'timestamp': '1624613160249', 'hashtags': ['EURO2020']}
# 348
# {'timestamp': '1624613160714', 'hashtags': ['FRA', 'SUI', 'CRO', 'ESP', 'ITA', 'AUT', 'BEL', 'POR']}
# 349
# 350
# {'timestamp': '1624613161440', 'hashtags': ['EURO2020']}
# 351
# 352
# 353
# 354
# {'timestamp': '1624613163179', 'hashtags': ['EURO2020']}
# 355
# {'timestamp': '1624613163321', 'hashtags': ['Finlande', 'Belgique', 'SaintPetersburg']}
# 356
# {'timestamp': '1624613164215', 'hashtags': ['ITA', 'AUT', 'VivoAzzurro', 'ITAAUT', 'ITA']}
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# {'timestamp': '1624613169218', 'hashtags': ['DieMannschaft', 'GER', 'EURO2020']}
# 364
# {'timestamp': '1624613169437', 'hashtags': ['EURO2020']}
# 365
# {'timestamp': '1624613169545', 'hashtags': ['GoalPointRatings', 'EURO2020']}
# 366
# {'timestamp': '1624613170200', 'hashtags': ['EURO2020']}
# 367
# 368
# {'timestamp': '1624613170690', 'hashtags': ['EURO2020']}
# 369
# 370
# {'timestamp': '1624613172518', 'hashtags': ['Téléphonesonne', 'football', 'politique']}
# 371
# 372
# 373
# 374
# 375
# {'timestamp': '1624613175632', 'hashtags': ['EURO2020', 'GER']}
# 376
# 377
# {'timestamp': '1624613176697', 'hashtags': ['EURO2020', 'VIVOY72']}
# 378
# 379
# 380
# {'timestamp': '1624613178717', 'hashtags': ['EURO2020', 'ويلز', 'الدنمارك']}
# 381
# {'timestamp': '1624613179107', 'hashtags': ['EURO2020']}
# 382
# 383
# {'timestamp': '1624613180016', 'hashtags': ['Euro2020']}
# 384
# 385
# {'timestamp': '1624613180617', 'hashtags': ['Téléphonesonne', 'football', 'politique']}
# 386
# 387
# 388
# 389
# {'timestamp': '1624613183720', 'hashtags': ['Euro2021', 'COVID19']}
# 390
# 391
# 392
# {'timestamp': '1624613185102', 'hashtags': ['EURO2020']}
# 393
# {'timestamp': '1624613185402', 'hashtags': ['EURO2020', 'POR']}
# 394
# 395
# {'timestamp': '1624613185612', 'hashtags': ['DEN', 'EURO2020']}
# 396
# {'timestamp': '1624613186129', 'hashtags': ['ManCity', 'EURO2020']}
# 397
# 398
# 399
# {'timestamp': '1624613186626', 'hashtags': ['Euro2020']}
# 400
# {'timestamp': '1624613187019', 'hashtags': ['EURO2020']}
# 401
# 402
# 403
# {'timestamp': '1624613188275', 'hashtags': ['EURO2020']}
# 404
# 405
# {'timestamp': '1624613188547', 'hashtags': ['Germany', 'BAGLE', 'EURO2020', 'Italy', 'Spain', 'Germany', 'Netherlands', 'Danmark', 'Austria', 'Sweden', 'DeFi']}
# 406
# {'timestamp': '1624613188561', 'hashtags': ['EURO2020', 'MCFC']}
# 407
# 408
# 409
# {'timestamp': '1624613189179', 'hashtags': ['fra', 'eng']}
# 410
# 411
# 412
# 413
# {'timestamp': '1624613191238', 'hashtags': ['EURO2020']}
# 414
# 415
# 416
# 417
# {'timestamp': '1624613193954', 'hashtags': ['BEL', 'POR', 'ITA', 'AUT', 'FRA', 'SUI', 'CRO', 'ESP']}
# 418
# 419
# {'timestamp': '1624613194643', 'hashtags': ['EUROSkills']}
# 420
# {'timestamp': '1624613194951', 'hashtags': ['EURO2020', 'Heineken']}
# 421
# {'timestamp': '1624613196364', 'hashtags': ['Heineken', 'musulmane']}
# 422
# 423
# {'timestamp': '1624613196785', 'hashtags': ['EURO2020']}
# 424
# {'timestamp': '1624613196949', 'hashtags': ['Euro2020']}
# 425
# {'timestamp': '1624613197931', 'hashtags': ['EURO2020']}
# 426
# {'timestamp': '1624613199410', 'hashtags': ['ManCity', 'ENG', 'EURO2020']}
# 427
# 428
# {'timestamp': '1624613199685', 'hashtags': ['DEN', 'EURO2020']}
# 429
# {'timestamp': '1624613200253', 'hashtags': ['ManCity', 'ENG', 'EURO2020']}
# 430
# 431
# {'timestamp': '1624613200610', 'hashtags': ['ENG', 'GER']}
# 432
# 433
# 434
# {'timestamp': '1624613201105', 'hashtags': ['EURO2020', 'GER']}
# 435
# 436
# {'timestamp': '1624613201301', 'hashtags': ['EURO2020']}
# 437
# {'timestamp': '1624613201424', 'hashtags': ['EURO2020']}
# 438
# {'timestamp': '1624613201672', 'hashtags': ['OTD']}
# 439
# {'timestamp': '1624613201794', 'hashtags': ['EURO2020']}
# 440
# {'timestamp': '1624613201536', 'hashtags': ['EURO2020', 'DEVILTIME']}
# 441
# {'timestamp': '1624613202138', 'hashtags': ['EURO2020']}
# 442
# {'timestamp': '1624613202244', 'hashtags': ['EURO2020']}
# 443
# 444
# {'timestamp': '1624613203441', 'hashtags': ['euro2020', 'europhoria', 'roundof16']}
# 445
# {'timestamp': '1624613203642', 'hashtags': ['EURO2020']}
# 446
# 447
# 448
# 449
# {'timestamp': '1624613204408', 'hashtags': ['EURO2020']}
# 450
# {'timestamp': '1624613204996', 'hashtags': ['ManCity', 'EURO2020']}
# 451
# 452
# 453
# 454
# 455
# {'timestamp': '1624613206441', 'hashtags': ['VamosComTudo']}
# 456
# {'timestamp': '1624613206915', 'hashtags': ['EURO2020']}
# 457
# 458
# 459
# 460
# 461
# 462
# {'timestamp': '1624613211998', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 463
# 464
# 465
# 466
# {'timestamp': '1624613213678', 'hashtags': ['EURO2020', 'VIVOY72']}
# 467
# 468
# 469
# {'timestamp': '1624613214208', 'hashtags': ['OTD']}
# 470
# 471
# 472
# 473
# 474
# {'timestamp': '1624613216231', 'hashtags': ['EURO2020']}
# 475
# {'timestamp': '1624613216276', 'hashtags': ['cmoncymru']}
# 476
# {'timestamp': '1624613216507', 'hashtags': ['ItaliaAustria', 'EURO2020']}
# 477
# 478
# 479
# 480
# {'timestamp': '1624613218636', 'hashtags': ['MUFC', 'EURO2020']}
# 481
# {'timestamp': '1624613218916', 'hashtags': ['EURO2020']}
# 482
# {'timestamp': '1624613219850', 'hashtags': ['EURO2020']}
# 483
# {'timestamp': '1624613220234', 'hashtags': ['EURO2020']}
# 484
# 485
# {'timestamp': '1624613220460', 'hashtags': ['EURO2020']}
# 486
# 487
# {'timestamp': '1624613221954', 'hashtags': ['EURO2020']}
# 488
# {'timestamp': '1624613222140', 'hashtags': ['EURO2020']}
# 489
# 490
# {'timestamp': '1624613224122', 'hashtags': ['gerhun', 'EURO2020']}
# 491
# {'timestamp': '1624613224368', 'hashtags': ['EURO2020']}
# 492
# {'timestamp': '1624613224416', 'hashtags': ['DieMannschaft', 'GER', 'EURO2020']}
# 493
# 494
# {'timestamp': '1624613225433', 'hashtags': ['ManCity', 'EURO2020']}
# 495
# 496
# {'timestamp': '1624613226608', 'hashtags': ['EURO2020', 'Heineken']}
# 497
# 498
# {'timestamp': '1624613228226', 'hashtags': ['EURO2020']}
# 499
# {'timestamp': '1624613228968', 'hashtags': ['EURO2020']}
# 500
# {'timestamp': '1624613229028', 'hashtags': ['EURO2020']}
# 501
# 502
# {'timestamp': '1624613231905', 'hashtags': ['EURO2020']}
# 503
# {'timestamp': '1624613233893', 'hashtags': ['DieMannschaft', 'GER', 'EURO2020']}
# 504
# {'timestamp': '1624613235144', 'hashtags': ['wembleystadium', 'uefa', 'ITAAUS']}
# 505
# {'timestamp': '1624613235092', 'hashtags': ['Austria', 'StyrianGP', 'EURO2020']}
# 506
# {'timestamp': '1624613236156', 'hashtags': ['gamblingeduction', 'gamblingharms', 'football', 'EURO2020']}
# 507
# {'timestamp': '1624613236882', 'hashtags': ['Euro2020', 'bière', 'Pogba', 'UEFA']}
# 508
# 509
# 510
# {'timestamp': '1624613238539', 'hashtags': ['EURO2020', 'CFC']}
# 511
# {'timestamp': '1624613238707', 'hashtags': ['ENG', 'GER', 'Euro2020']}
# 512
# 513
# 514
# {'timestamp': '1624613240575', 'hashtags': ['ENG', 'GER']}
# 515
# {'timestamp': '1624613241242', 'hashtags': ['EURO2020']}
# 516
# {'timestamp': '1624613241333', 'hashtags': ['gekisaka']}
# 517
# {'timestamp': '1624613241667', 'hashtags': ['EURO2020', 'WhistlePodu', 'Yellove', 'kadaikutty']}
# 518
# {'timestamp': '1624613242844', 'hashtags': ['EURO2020']}
# 519
# {'timestamp': '1624613242901', 'hashtags': ['EURO2020']}
# 520
# 521
# 522
# {'timestamp': '1624613244144', 'hashtags': ['Euro2020']}
# 523
# {'timestamp': '1624613244492', 'hashtags': ['AUT']}
# 524
# {'timestamp': '1624613244905', 'hashtags': ['Euro2020']}
# 525
# 526
# 527
# 528
# {'timestamp': '1624613245796', 'hashtags': ['EURO2020']}
# 529
# 530
# {'timestamp': '1624613246211', 'hashtags': ['EURO2020']}
# 531
# {'timestamp': '1624613247247', 'hashtags': ['ManCity']}
# 532
# {'timestamp': '1624613247432', 'hashtags': ['VamosComTudo']}
# 533
# 534
# {'timestamp': '1624613247776', 'hashtags': ['EURO2020']}
# 535
# 536
# 537
# {'timestamp': '1624613248982', 'hashtags': ['ManCity']}
# 538
# {'timestamp': '1624613249460', 'hashtags': ['ManCity', 'ENG', 'EURO2020']}
# 539
# 540
# {'timestamp': '1624613249662', 'hashtags': ['Euro2020']}
# 541
# {'timestamp': '1624613250281', 'hashtags': ['FRA', 'EURO2020']}
# 542
# {'timestamp': '1624613250616', 'hashtags': ['EURO2020']}
# 543
# {'timestamp': '1624613250636', 'hashtags': ['Giveaways', 'Concours']}
# 544
# 545
# {'timestamp': '1624613254009', 'hashtags': ['EURO2020', 'MCFC']}
# 546
# 547
# {'timestamp': '1624613254126', 'hashtags': ['EURO2020']}
# 548
# {'timestamp': '1624613254591', 'hashtags': ['ITA']}
# 549
# 550
# {'timestamp': '1624613255362', 'hashtags': ['EURO2020']}
# 551
# {'timestamp': '1624613255714', 'hashtags': ['DieMannschaft', 'GER', 'EURO2020']}
# 552
# {'timestamp': '1624613255856', 'hashtags': ['DEVILTIME', 'EURO2020']}
# 553
# 554
# {'timestamp': '1624613256260', 'hashtags': ['EURO2020', 'Lewandowski', 'Torres', 'Ronaldo', 'Havertz']}
# 555
# 556
# 557
# 558
# 559
# {'timestamp': '1624613257403', 'hashtags': ['ENG', 'GER']}
# 560
# 561
# {'timestamp': '1624613257868', 'hashtags': ['BAGLE', 'EURO2020', 'Italy', 'Spain', 'Germany']}
# 562
# {'timestamp': '1624613258209', 'hashtags': ['EURO2020']}
# 563
# 564
# {'timestamp': '1624613258579', 'hashtags': ['gerhun', 'EURO2020']}
# 565
# 566
# {'timestamp': '1624613258914', 'hashtags': ['ENG', 'GER']}
# 567
# {'timestamp': '1624613258962', 'hashtags': ['EURO2020', 'VIVOY72']}
# 568
# 569
# 570
# {'timestamp': '1624613260009', 'hashtags': ['EURO2020']}
# 571
# 572
# {'timestamp': '1624613260308', 'hashtags': ['EURO2020', 'MCFC']}
# 573
# {'timestamp': '1624613260455', 'hashtags': ['ManCity', 'ENG', 'EURO2020']}
# 574
# 575
# 576
# {'timestamp': '1624613261682', 'hashtags': ['ITA', 'AUT', 'VivoAzzurro', 'ITAAUT', 'ITA']}
# 577
# 578
# 579
# {'timestamp': '1624613263982', 'hashtags': ['EURO2020']}
# 580
# 581
# {'timestamp': '1624613265246', 'hashtags': ['EURO2020']}
# 582
# 583
# 584
# {'timestamp': '1624613267582', 'hashtags': ['DEVILTIME', 'EURO2020']}
# 585
# {'timestamp': '1624613267775', 'hashtags': ['ItaliaAustria', 'EURO2020']}
# 586
# {'timestamp': '1624613268557', 'hashtags': ['EURO2020']}
# 587
# {'timestamp': '1624613268748', 'hashtags': ['France', 'Paris', 'EURO2020', 'Euro2021', 'PCR']}
# 588
# 589
# {'timestamp': '1624613270589', 'hashtags': ['EURO2020']}
# 590
# {'timestamp': '1624613271526', 'hashtags': ['ENG', 'GER']}
# 591
# {'timestamp': '1624613271785', 'hashtags': ['EURO2020']}
# 592
# {'timestamp': '1624613273937', 'hashtags': ['Goretzka']}
# 593
# 594
# 595
# {'timestamp': '1624613274818', 'hashtags': ['EURO2020']}
# 596
# {'timestamp': '1624613275222', 'hashtags': ['EURO2020', 'PORFRA', 'GERHUN']}
# 597
# 598
# {'timestamp': '1624613275440', 'hashtags': ['EURO2020']}
# 599
# 600
# 601
# 602
# 603
# {'timestamp': '1624613276247', 'hashtags': ['EURO2020']}
# 604
# {'timestamp': '1624613279498', 'hashtags': ['ITAAUS', 'Euro2020', 'Euro2021']}
# 605
# 606
# {'timestamp': '1624613280517', 'hashtags': ['por']}
# 607
# 608
# {'timestamp': '1624613281349', 'hashtags': ['ForDanmark', 'EURO2020', 'DEN']}
# 609
# 610
# {'timestamp': '1624613283010', 'hashtags': ['EURO2020']}
# 611
# 612
# {'timestamp': '1624613283441', 'hashtags': ['FRA', 'EURO2020']}
# 613
# {'timestamp': '1624613283618', 'hashtags': ['EURO2020']}
# 614
# 615
# {'timestamp': '1624613284190', 'hashtags': ['ENG', 'GER']}
# 616
